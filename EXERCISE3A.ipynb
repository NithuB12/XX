# %%
import pandas as pd
a=pd.read_excel("/content/Mark.xlsx")
#get the table data
print("Get the table data:\n")
print(a)

#print d to string
print(a.to_string())
df=pd.DataFrame(a)
print(df)

#to get column heading
print("\nGet the column heading:\n",df.columns)

#to get the shape ( no. of rows, no. of columns)
print("\nGet the shape(no. of rows, no. of columns)\n",df.shape)

#to get particular column values
print("\nGet particular column values:\n",df["roll number"])

#extract/slice the table values ( include this row, exclude this row)
print("\nExtract/slice the table values-[including this row,exluding this row]:\n",df[2:5])

#to get the particular row values through row number identification
print("\nGet the row values through row identification\n",df.loc[7])

#to get the row values through roll number identification
print("\nGet the row value through roll number identification\n",a.loc[a["roll number"]==105])

#to get average of total values
df=a["total"]/3
print("\nAverage of the total marks:\n",df)
# Out:
# Get the table data:
#
#     Unnamed: 0  Unnamed: 1  roll number     name  maths  science  social  \
# 0          NaN         NaN          100      Abi     50       30      40
# 1          NaN         NaN          101     subi     40       60      30
# 2          NaN         NaN          102     baby     40       30      20
# 3          NaN         NaN          103     poni     30       40      60
# 4          NaN         NaN          104     reva     70       80      90
# 5          NaN         NaN          105  bhavani     30       20      10
# 6          NaN         NaN          106     remo     90       60      30
# 7          NaN         NaN          107   karthi     80       30      20
# 8          NaN         NaN          108  sumathi     30       40      50
# 9          NaN         NaN          109  sowmiya     40       30      40
# 10         NaN         NaN          110   kamesh     50       50      60
#
#     total
# 0     120
# 1     130
# 2      90
# 3     130
# ...
