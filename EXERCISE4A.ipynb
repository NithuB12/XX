# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f','g','h'])
print("Original dataframe with NaN\n",df)
print("\n")
print("Dropped dataframe\n",df.dropna())
print("\n")

df=pd.DataFrame(np.random.randn(3,3),index=['a','c','e'],columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original dataframe\n",df)
print("\n")
print("NaN replaced with 0\n")
print(df.fillna(0))

df = pd.DataFrame({'one':[10,20,30,40,50,2000],
'two':[1000,0,30,40,50,60]})
print("\nOriginal DataFrame:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({1000:10,2000:60,40:400,0:100}))

df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f', 'h'], columns=['one', 'two', 'three'])
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
print("\nOriginal DataFrame:\n",df)
print("\nNan- with True fill:\n")
print (df['one'].isnull())

df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
print("\nOriginal DataFrame:\n",df)
print("\nNaN - Filled with Forward values:\n")
print (df.fillna(method='pad'))
print("\nNaN - Filled with Background values:\n")
print (df.fillna(method='bfill'))
# Out:
# Original dataframe with NaN
#          one       two     three
# a -0.183309 -0.316533 -0.134482
# b       NaN       NaN       NaN
# c -0.299763  0.546135  0.010220
# d       NaN       NaN       NaN
# e  0.023888 -0.590957  0.352811
# f  0.741837 -1.490565 -0.373950
# g       NaN       NaN       NaN
# h -0.335317 -0.300369  1.444608
#
#
# Dropped dataframe
#          one       two     three
# a -0.183309 -0.316533 -0.134482
# c -0.299763  0.546135  0.010220
# e  0.023888 -0.590957  0.352811
# f  0.741837 -1.490565 -0.373950
# h -0.335317 -0.300369  1.444608
#
#
# Original dataframe
#          one       two     three
# a -1.583544  0.190487 -0.916968
# b       NaN       NaN       NaN
# c -0.855176  0.072330  0.197110
#
#
# NaN replaced with 0
#
#         one       two     three
# a -1.583544  0.190487 -0.916968
# b  0.000000  0.000000  0.000000
# c -0.855176  0.072330  0.197110
#
# Original DataFrame:
#      one   two
# 0    10  1000
# 1    20     0
# 2    30    30
# 3    40    40
# 4    50    50
# 5  2000    60
#
#  DataFrame with replaced values:
#
#    one  two
# 0   10   10
# 1   20  100
# 2   30   30
# 3  400  400
# 4   50   50
# 5   60   60
#
# Original DataFrame:
#          one       two     three
# a  1.154721 -0.564760 -1.444203
# b       NaN       NaN       NaN
# c -1.310657  0.516676  2.111641
# d       NaN       NaN       NaN
# e  1.209215 -0.276638 -2.134083
# f  0.865236 -0.485305  0.420501
# g       NaN       NaN       NaN
# h -0.586121 -0.570917 -0.113142
#
# Nan- with True fill:
#
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool
#
# Original DataFrame:
#          one       two     three
# a -0.305263  0.642493  0.172186
# b       NaN       NaN       NaN
# c -0.298949  0.686616 -0.716714
# d       NaN       NaN       NaN
# e -0.222214  0.612001 -0.466536
# f -0.473984  1.736417 -0.962851
# g       NaN       NaN       NaN
# h -1.178297 -0.389174  0.347697
#
# NaN - Filled with Forward values:
#
#         one       two     three
# a -0.305263  0.642493  0.172186
# b -0.305263  0.642493  0.172186
# c -0.298949  0.686616 -0.716714
# d -0.298949  0.686616 -0.716714
# e -0.222214  0.612001 -0.466536
# f -0.473984  1.736417 -0.962851
# g -0.473984  1.736417 -0.962851
# h -1.178297 -0.389174  0.347697
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.305263  0.642493  0.172186
# b -0.298949  0.686616 -0.716714
# c -0.298949  0.686616 -0.716714
# d -0.222214  0.612001 -0.466536
# e -0.222214  0.612001 -0.466536
# f -0.473984  1.736417 -0.962851
# g -1.178297 -0.389174  0.347697
# h -1.178297 -0.389174  0.347697
# <ipython-input-1-e9a16e462a6b>:34: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print (df.fillna(method='pad'))
# <ipython-input-1-e9a16e462a6b>:36: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print (df.fillna(method='bfill'))
